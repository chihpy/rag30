# %%
import os

from utils import json_load

# %%
# get evaluator result 
eval_dir = os.path.join('data', 'deliverables', "prompt_correctness")
eval_file_path = os.path.join(eval_dir, '2_llama_zh.json')
eval_data = json_load(eval_file_path)  # given qid and get detail
eval_data['1']
# Out:
# load data from: data/deliverables/prompt_correctness/2_llama_zh.json
# {'reference_answer': {'qid': '1',
#   'stem': '常見針灸配穴法中,所指的「四關穴」,為下列何穴位之組合?',
#   'A': '上星、日月',
#   'B': '合谷、太衝',
#   'C': '內關、外關',
#   'D': '上關、下關'},
#  'response': {'A': '三村台终飯加度。',
#   'B': '吃条台终飯加度。',
#   'C': '六南分。三村台终飯加度。',
#   'D': '一条台终飯加度。',
#   'ans': None,
#   'qid': 1,
#   'stem': '台九気终飯加度泩。吃的“六南分。，是一条有分题不别的宽器。'},
#  'score': 1.0,
#  'feedback': '生成答案與原始題目內容無關且多為亂碼，題幹（stem）被錯誤提取/變造，選項也不符合原文，雖然 qid 有值但因為題幹與選項皆不正確/無意義，判定為不相關（最差）。',
#  'ispass': False}

# %%
dataset_dir = os.path.join('data', 'source', 'normalized_exact_match_result')
print(os.listdir(dataset_dir))
label_file_path = os.path.join(dataset_dir, '2_llama_zh_evaluation_result.json')
label_data = json_load(label_file_path)
# Out:
# ['5_json_gemma_evaluation_result.json', '2_llama_zh_evaluation_result.json', '1_llama_en_evaluation_result.json', '3_llama_chat_evaluation_result.json', '4_gemma_evaluation_result.json']
# load data from: data/source/normalized_exact_match_result/2_llama_zh_evaluation_result.json

# %%
label_data
# Out:
# [{'qid': '1',
#   'ispass': False,
#   'label': '常見針灸配穴法中,所指的「四關穴」,為下列何穴位之組合?',
#   'pred': '台九気终飯加度泩。吃的“六南分。，是一条有分题不别的宽器。',
#   'nlabel': '常見針灸配穴法中所指的四關穴為下列何穴位之組合',
#   'npred': '台九気终飯加度泩吃的六南分是一条有分题不别的宽器'},
#  {'qid': '2',
#   'ispass': False,
#   'label': '依《靈樞.經脈》記載,「其直者,從巔入絡腦,還出別下項,循肩膊內,挾脊抵腰中」,指下列 何經的循行內容?',
#   'pred': '',
#   'nlabel': '依靈樞經脈記載其直者從巔入絡腦還出別下項循肩膊內挾脊抵腰中指下列何經的循行內容',
#   'npred': ''},
#  {'qid': '3',
#   'ispass': False,
#   'label': '依《靈樞.經脈》所記載:「是主筋所生病者,痔、瘧、狂、癲疾、頭顖、項痛,目黃、淚出,鼽 衄,項、背、腰、尻、膕、腨、腳皆痛,小趾不用」,指何經的病證內容?',
#   'pred': '3.依《靈樞．經脈》所記載：\u3000\u3000“是主筋所生病者，痔、瘧、狂、癲疾、頭顖、項痛，目黃、淚出，鼽衄，項、背、腰、尻、膕、腨、腳皆痛，小趾不用”，指何經的病證內容？',
#   'nlabel': '依靈樞經脈所記載是主筋所生病者痔瘧狂癲疾頭顖項痛目黃淚出鼽衄項背腰尻膕腨腳皆痛小趾不用指何經的病證內容',
#   'npred': '3依靈樞經脈所記載是主筋所生病者痔瘧狂癲疾頭顖項痛目黃淚出鼽衄項背腰尻膕腨腳皆痛小趾不用指何經的病證內容'},
#  {'qid': '4',
#   'ispass': False,
#   'label': '有關腧穴之國際譯名,外丘之編號為何?',
#   'pred': '常东海纨く六台，割十是、。',
#   'nlabel': '有關腧穴之國際譯名外丘之編號為何',
#   'npred': '常东海纨く六台割十是'},
#  {'qid': '5',
#   'ispass': True,
#   'label': '下列何者為陰維脈之郄穴?',
#   'pred': '下列何者為陰維脈之郄穴?',
#   'nlabel': '下列何者為陰維脈之郄穴',
#   'npred': '下列何者為陰維脈之郄穴'},
#  {'qid': '6',
#   'ispass': True,
#   'label': '下列何者為足太陰脾經之絡穴?',
#   'pred': '下列何者為足太陰脾經之絡穴？',
#   'nlabel': '下列何者為足太陰脾經之絡穴',
#   'npred': '下列何者為足太陰脾經之絡穴'},
#  {'qid': '7',
#   'ispass': True,
#   'label': '依《難經.六十八難》,下列何穴主心下滿?',
#   'pred': '依《難經．六十八難》，下列何穴主心下滿？',
#   'nlabel': '依難經六十八難下列何穴主心下滿',
#   'npred': '依難經六十八難下列何穴主心下滿'},
#  {'qid': '8',
#   'ispass': False,
#   'label': '有關足太陰脾經的重要腧穴,下列敘述何者正確?',
#   'pred': '常东浦形素台的适合芳食封切，一条明规是化王。',
#   'nlabel': '有關足太陰脾經的重要腧穴下列敘述何者正確',
#   'npred': '常东浦形素台的适合芳食封切一条明规是化王'},
#  {'qid': '9',
#   'ispass': True,
#   'label': '下列穴位屬三焦經與膽經的交會穴共有幾個?1臑會 2顴髎 3秉風 4聽宮 5耳門',
#   'pred': '下列穴位屬三焦經與膽經的交會穴共有幾個？\n\n①臑會\u3000②顴髎\u3000③秉風\u3000④聽宮\u3000⑤耳門\n\n',
#   'nlabel': '下列穴位屬三焦經與膽經的交會穴共有幾個1臑會2顴髎3秉風4聽宮5耳門',
#   'npred': '下列穴位屬三焦經與膽經的交會穴共有幾個1臑會2顴髎3秉風4聽宮5耳門'},
#  {'qid': '10',
#   'ispass': True,
#   'label': '有關手少陰心經的「通里穴」,下列敘述共幾項正確?1手少陰心經的郄穴 2馬丹陽天星十二穴 之一 3距離靈道穴五分 4配內關,治心絞痛',
#   'pred': '有關手少陰心經的「通里穴」，下列敘述共幾項正確？①手少陰心經的郄穴\u3000②馬丹陽天星十二穴之一\u3000③距離靈道穴五分\u3000④配內關，治心絞痛\n',
#   'nlabel': '有關手少陰心經的通里穴下列敘述共幾項正確1手少陰心經的郄穴2馬丹陽天星十二穴之一3距離靈道穴五分4配內關治心絞痛',
#   'npred': '有關手少陰心經的通里穴下列敘述共幾項正確1手少陰心經的郄穴2馬丹陽天星十二穴之一3距離靈道穴五分4配內關治心絞痛'},
#  {'qid': '11',
#   'ispass': True,
#   'label': '下列何穴較不適用於治療落枕?',
#   'pred': '下列何穴較不適用於治療落枕？',
#   'nlabel': '下列何穴較不適用於治療落枕',
#   'npred': '下列何穴較不適用於治療落枕'},
#  {'qid': '12',
#   'ispass': True,
#   'label': '下列何穴最適合治療瘰癧?',
#   'pred': '下列何穴最適合治療瘰癧？',
#   'nlabel': '下列何穴最適合治療瘰癧',
#   'npred': '下列何穴最適合治療瘰癧'},
#  {'qid': '13',
#   'ispass': True,
#   'label': '肝經的五腧穴為下列那一組?',
#   'pred': '肝經的五腧穴為下列那一組？',
#   'nlabel': '肝經的五腧穴為下列那一組',
#   'npred': '肝經的五腧穴為下列那一組'},
#  {'qid': '14',
#   'ispass': False,
#   'label': '有關足陽明胃經的五腧穴,下列敘述何者錯誤?',
#   'pred': '带为洏黄谄约的五分务内，了合的说回是带为六家天',
#   'nlabel': '有關足陽明胃經的五腧穴下列敘述何者錯誤',
#   'npred': '带为洏黄谄约的五分务内了合的说回是带为六家天'},
#  {'qid': '15',
#   'ispass': False,
#   'label': '有關商丘穴之敘述,下列何者錯誤?',
#   'pred': '平东海程的做诹，了企难是一代锓姐?',
#   'nlabel': '有關商丘穴之敘述下列何者錯誤',
#   'npred': '平东海程的做诹了企难是一代锓姐'},
#  {'qid': '16',
#   'ispass': False,
#   'label': '有關本神穴的敘述,下列選項何者正確?1上入髮際一寸。從神庭外開二寸處 2曲差旁一寸五分  3可治頭痛,目眩等 4配百會、人中、十宣,治中風不省人事',
#   'pred': '',
#   'nlabel': '有關本神穴的敘述下列選項何者正確1上入髮際一寸從神庭外開二寸處2曲差旁一寸五分3可治頭痛目眩等4配百會人中十宣治中風不省人事',
#   'npred': ''},
#  {'qid': '17',
#   'ispass': True,
#   'label': '有關任脈穴位之敘述,下列何者正確?',
#   'pred': '有關任脈穴位之敘述，下列何者正確？',
#   'nlabel': '有關任脈穴位之敘述下列何者正確',
#   'npred': '有關任脈穴位之敘述下列何者正確'},
#  {'qid': '18',
#   'ispass': False,
#   'label': '大椎穴位於下列何處?',
#   'pred': '王当訽锩求了三回缩求一。',
#   'nlabel': '大椎穴位於下列何處',
#   'npred': '王当訽锩求了三回缩求一'},
#  {'qid': '19',
#   'ispass': True,
#   'label': '下列何種方式不是轉針迎隨補瀉法中的瀉法?',
#   'pred': '下列何種方式不是轉針迎隨補瀉法中的瀉法？',
#   'nlabel': '下列何種方式不是轉針迎隨補瀉法中的瀉法',
#   'npred': '下列何種方式不是轉針迎隨補瀉法中的瀉法'},
#  {'qid': '20',
#   'ispass': True,
#   'label': '下列何者是《刺灸心法要訣》的禁針穴?',
#   'pred': '下列何者是《刺灸心法要訣》的禁針穴？',
#   'nlabel': '下列何者是刺灸心法要訣的禁針穴',
#   'npred': '下列何者是刺灸心法要訣的禁針穴'},
#  {'qid': '21',
#   'ispass': False,
#   'label': '依《靈樞.九針十二原》,有關鈹針的敘述,下列何者錯誤?',
#   'pred': '笔义、龙海小右化，合用量横元的把见的明称，三代、巴答右體、南在海注、一分的见关。',
#   'nlabel': '依靈樞九針十二原有關鈹針的敘述下列何者錯誤',
#   'npred': '笔义龙海小右化合用量横元的把见的明称三代巴答右體南在海注一分的见关'},
#  {'qid': '22',
#   'ispass': False,
#   'label': '有關「艾」之敘述,下列何者正確?',
#   'pred': '平东是“取”的答合，代不有说明？',
#   'nlabel': '有關艾之敘述下列何者正確',
#   'npred': '平东是取的答合代不有说明'},
#  {'qid': '23',
#   'ispass': True,
#   'label': '有關艾的品質鑑定,下列何者為優質品?',
#   'pred': '有關艾的品質鑑定，下列何者為優質品？',
#   'nlabel': '有關艾的品質鑑定下列何者為優質品',
#   'npred': '有關艾的品質鑑定下列何者為優質品'},
#  {'qid': '24',
#   'ispass': False,
#   'label': '臨床上的拔罐療法之濕杯術,下列何者不宜使用?',
#   'pred': '等永的抠帽环注是代的回台化。一地有五切性的人、三层苹起的人、种子性注了的人、回台施消的人',
#   'nlabel': '臨床上的拔罐療法之濕杯術下列何者不宜使用',
#   'npred': '等永的抠帽环注是代的回台化一地有五切性的人三层苹起的人种子性注了的人回台施消的人'},
#  {'qid': '25',
#   'ispass': True,
#   'label': '有關中風患者使用頭皮針之技術,下列敘述何者錯誤?',
#   'pred': '有關中風患者使用頭皮針之技術，下列敘述何者錯誤？',
#   'nlabel': '有關中風患者使用頭皮針之技術下列敘述何者錯誤',
#   'npred': '有關中風患者使用頭皮針之技術下列敘述何者錯誤'},
#  {'qid': '26',
#   'ispass': False,
#   'label': '患者中風後一側肢體癱瘓,其針灸治療穴組,不包括下列何者?',
#   'pred': '私人前漸天合钷師的福园芫飯化,仅台览服区品工分,一些条的系给名别，不截吗台览服区品工分:\n\nA.中直,家寸\nB.钷黄,南加\nC.更座,合尺\nD.绱路,起三园',
#   'nlabel': '患者中風後一側肢體癱瘓其針灸治療穴組不包括下列何者',
#   'npred': '私人前漸天合钷師的福园芫飯化仅台览服区品工分一些条的系给名别不截吗台览服区品工分a中直家寸b钷黄南加c更座合尺d绱路起三园'},
#  {'qid': '27',
#   'ispass': False,
#   'label': '以「五十肩」之疼痛部位為基礎,臨床上循經取穴之敘述,下列何者錯誤?',
#   'pred': '27. 以 "丽十迊尊等。代的回注利一中會为台三苹功为尊等、勓小为递注提现。代的回注利、台三苹功、尊等、勓小为递注提现。代的回注利、台三苹功、尊等、勓小为递注提现。',
#   'nlabel': '以五十肩之疼痛部位為基礎臨床上循經取穴之敘述下列何者錯誤',
#   'npred': '27以丽十迊尊等代的回注利一中會为台三苹功为尊等勓小为递注提现代的回注利台三苹功尊等勓小为递注提现代的回注利台三苹功尊等勓小为递注提现'},
#  {'qid': '28',
#   'ispass': False,
#   'label': '48歲女性患者,診斷為類風濕性關節炎已2年,主訴四肢肩膀至手指遊走性疼痛,夜間及氣候變化 疼痛加重。下列敘述何者錯誤?',
#   'pred': '下列敘述何者錯誤？\n\n28.48歲女性患者，診斷為類風濕性關節炎已2年，主訴四肢肩膀至手指遊走性疼痛，夜間及氣候變化疼痛加重。\n\nA.由於體虛感受風寒濕邪留滯\nB.腫痛時，可用灸療\nC.膝關節疼痛，選用犢鼻\nD.肩關節疼痛，針刺肩髃、肩井',
#   'nlabel': '48歲女性患者診斷為類風濕性關節炎已2年主訴四肢肩膀至手指遊走性疼痛夜間及氣候變化疼痛加重下列敘述何者錯誤',
#   'npred': '下列敘述何者錯誤2848歲女性患者診斷為類風濕性關節炎已2年主訴四肢肩膀至手指遊走性疼痛夜間及氣候變化疼痛加重a由於體虛感受風寒濕邪留滯b腫痛時可用灸療c膝關節疼痛選用犢鼻d肩關節疼痛針刺肩髃肩井'},
#  {'qid': '29',
#   'ispass': True,
#   'label': '依《刺灸心法要訣》:「牙齒疼痛,手腕無力疼痛,及咳嗽風痰,偏正頭疼」諸症,宜取下列何 穴?',
#   'pred': '依《刺灸心法要訣》：\u3000\u3000牙齒疼痛，手腕無力疼痛，及咳嗽風痰，偏正頭疼諸症，宜取下列何穴？',
#   'nlabel': '依刺灸心法要訣牙齒疼痛手腕無力疼痛及咳嗽風痰偏正頭疼諸症宜取下列何穴',
#   'npred': '依刺灸心法要訣牙齒疼痛手腕無力疼痛及咳嗽風痰偏正頭疼諸症宜取下列何穴'},
#  {'qid': '30',
#   'ispass': False,
#   'label': '下列何種疾病不是便秘的病因?',
#   'pred': '简小为发深的六交は？\nB.终體構现',
#   'nlabel': '下列何種疾病不是便秘的病因',
#   'npred': '简小为发深的六交はb终體構现'},
#  {'qid': '31',
#   'ispass': False,
#   'label': '有關急性哮喘的針灸治療,下列敘述何者錯誤?',
#   'pred': '简义得飕気的发起有观工，为合、对常的经分。》》A. 素度可工有六小刪已带布》》B. 动为南，苹对》》C. 化可工，现得30分秒，前布5、三分终工》》D. 明动发起时，手代种天化的服务经分工》',
#   'nlabel': '有關急性哮喘的針灸治療下列敘述何者錯誤',
#   'npred': '简义得飕気的发起有观工为合对常的经分a素度可工有六小刪已带布b动为南苹对c化可工现得30分秒前布5三分终工d明动发起时手代种天化的服务经分工'},
#  {'qid': '32',
#   'ispass': True,
#   'label': '下列何穴最不適合用於治療小兒遺尿?',
#   'pred': '下列何穴最不適合用於治療小兒遺尿？',
#   'nlabel': '下列何穴最不適合用於治療小兒遺尿',
#   'npred': '下列何穴最不適合用於治療小兒遺尿'},
#  {'qid': '33',
#   'ispass': False,
#   'label': '28歲李先生搬家工人,工作需要搬負重物,半年前陰囊腫脹疼痛,少腹牽連疼痛,立則下墜,臥則 入腹,初起疼痛較甚,近日不覺痛楚,僅陰囊偏大,下列敘述何者錯誤?',
#   'pred': '下列敘述何者錯誤？',
#   'nlabel': '28歲李先生搬家工人工作需要搬負重物半年前陰囊腫脹疼痛少腹牽連疼痛立則下墜臥則入腹初起疼痛較甚近日不覺痛楚僅陰囊偏大下列敘述何者錯誤',
#   'npred': '下列敘述何者錯誤'},
#  {'qid': '34',
#   'ispass': False,
#   'label': '「針灸復興」或「針灸熱潮」是起源於那個事件被國際媒體重視報導,進一步引起一系列的學術研 究,始被廣泛利用?',
#   'pred': '',
#   'nlabel': '針灸復興或針灸熱潮是起源於那個事件被國際媒體重視報導進一步引起一系列的學術研究始被廣泛利用',
#   'npred': ''},
#  {'qid': '35',
#   'ispass': True,
#   'label': '依「主客原絡」之原則,肺經病咳喘,可以先取太淵穴,再配何穴位?',
#   'pred': '依 “主客原絡” 之原則，肺經病咳喘，可以先取太淵穴，再配何穴位？',
#   'nlabel': '依主客原絡之原則肺經病咳喘可以先取太淵穴再配何穴位',
#   'npred': '依主客原絡之原則肺經病咳喘可以先取太淵穴再配何穴位'},
#  {'qid': '36',
#   'ispass': False,
#   'label': '《傷寒論》原著中所記載之穴位,不包括下列何者?1風門 2脾俞 3風府 4肝俞 5京門',
#   'pred': '',
#   'nlabel': '傷寒論原著中所記載之穴位不包括下列何者1風門2脾俞3風府4肝俞5京門',
#   'npred': ''},
#  {'qid': '37',
#   'ispass': False,
#   'label': '根據《靈樞.經脈》的原文,古人敘述經絡分布的形容詞共有三十九個字詞,下列何者錯誤?',
#   'pred': '',
#   'nlabel': '根據靈樞經脈的原文古人敘述經絡分布的形容詞共有三十九個字詞下列何者錯誤',
#   'npred': ''},
#  {'qid': '38',
#   'ispass': False,
#   'label': '切脈為中醫診病之重要手段,有關脈動部位之敘述,下列何者錯誤?',
#   'pred': '笔海是三国语小未化會的亡台目,一条一面名答的明称，事一条一面对。',
#   'nlabel': '切脈為中醫診病之重要手段有關脈動部位之敘述下列何者錯誤',
#   'npred': '笔海是三国语小未化會的亡台目一条一面名答的明称事一条一面对'},
#  {'qid': '39',
#   'ispass': True,
#   'label': '根據《靈樞.經脈》,關於足陽明胃經的循行及病候敘述,下列何者錯誤?',
#   'pred': '根據《靈樞．經脈》，關於足陽明胃經的循行及病候敘述，下列何者錯誤？',
#   'nlabel': '根據靈樞經脈關於足陽明胃經的循行及病候敘述下列何者錯誤',
#   'npred': '根據靈樞經脈關於足陽明胃經的循行及病候敘述下列何者錯誤'},
#  {'qid': '40',
#   'ispass': False,
#   'label': '根據《靈樞.經脈》,關於手太陽小腸經的循行及病候敘述,下列何者錯誤?',
#   'pred': '根據《靈樞．經脈》，關於手太陽小腸經的循行及病候敘述，下列何者錯誤？\n\nA.起於小指次指之端，循手外側上腕，出踝中\nB.其支者，從缺盆，循頸，上頰，至目銳眥，卻入耳中\nC.是動則病，嗌痛，頷腫，不可以顧，肩似拔，臑似折\nD.是主液所生病者',
#   'nlabel': '根據靈樞經脈關於手太陽小腸經的循行及病候敘述下列何者錯誤',
#   'npred': '根據靈樞經脈關於手太陽小腸經的循行及病候敘述下列何者錯誤a起於小指次指之端循手外側上腕出踝中b其支者從缺盆循頸上頰至目銳眥卻入耳中c是動則病嗌痛頷腫不可以顧肩似拔臑似折d是主液所生病者'},
#  {'qid': '41',
#   'ispass': False,
#   'label': '關於經別、別絡、經筋、皮部的敘述,下列何者錯誤?',
#   'pred': '笔为得发，崇起。得加。朿泩。璼角的明组，代一目锓度？',
#   'nlabel': '關於經別別絡經筋皮部的敘述下列何者錯誤',
#   'npred': '笔为得发崇起得加朿泩璼角的明组代一目锓度'},
#  {'qid': '42',
#   'ispass': False,
#   'label': '針灸腧穴「中行上腹部」在人體的分布,下列何者錯誤?',
#   'pred': '台尺测踪终飯皮 利种三角前靡工 圣代的合台，一条了锓度?',
#   'nlabel': '針灸腧穴中行上腹部在人體的分布下列何者錯誤',
#   'npred': '台尺测踪终飯皮利种三角前靡工圣代的合台一条了锓度'},
#  {'qid': '43',
#   'ispass': False,
#   'label': '病患主訴呼吸喘促、咳嗽頻發,依據主客原絡法取穴,下列何者正確?',
#   'pred': '依據主客原絡法取穴，下列何者正確？',
#   'nlabel': '病患主訴呼吸喘促咳嗽頻發依據主客原絡法取穴下列何者正確',
#   'npred': '依據主客原絡法取穴下列何者正確'},
#  {'qid': '44',
#   'ispass': True,
#   'label': '下列何穴位不是位於第一、二肋間的水平高度上?',
#   'pred': '下列何穴位不是位於第一、二肋間的水平高度上？',
#   'nlabel': '下列何穴位不是位於第一二肋間的水平高度上',
#   'npred': '下列何穴位不是位於第一二肋間的水平高度上'},
#  {'qid': '45',
#   'ispass': False,
#   'label': '有關「肩外俞」穴與「肩中俞」穴之敘述,下列何者錯誤?',
#   'pred': '尽东武载。代不有反子，已不想见放到犻南。',
#   'nlabel': '有關肩外俞穴與肩中俞穴之敘述下列何者錯誤',
#   'npred': '尽东武载代不有反子已不想见放到犻南'},
#  {'qid': '46',
#   'ispass': False,
#   'label': '有關「秉風」穴之敘述,下列何者錯誤?',
#   'pred': '常代澛素切的做话，了三目名别。',
#   'nlabel': '有關秉風穴之敘述下列何者錯誤',
#   'npred': '常代澛素切的做话了三目名别'},
#  {'qid': '47',
#   'ispass': False,
#   'label': '腕骨、陽谷、養老、少海、臑會、天宗、肩井、肩中俞、天鼎、巨髎、聽會。以上穴位屬於小腸經 者有幾個?',
#   'pred': '台为截卡，阶座，半天，小浦，讯园，甲南台，主三务，甲南中务，张浦，黄园，合台代天。代见截卡等的會数小相到一丂？',
#   'nlabel': '腕骨陽谷養老少海臑會天宗肩井肩中俞天鼎巨髎聽會以上穴位屬於小腸經者有幾個',
#   'npred': '台为截卡阶座半天小浦讯园甲南台主三务甲南中务张浦黄园合台代天代见截卡等的會数小相到一丂'},
#  {'qid': '48',
#   'ispass': True,
#   'label': '根據《針灸科學》,下列何者為與足背太衝穴內外相對的穴位?',
#   'pred': '根據《針灸科學》，下列何者為與足背太衝穴內外相對的穴位？',
#   'nlabel': '根據針灸科學下列何者為與足背太衝穴內外相對的穴位',
#   'npred': '根據針灸科學下列何者為與足背太衝穴內外相對的穴位'},
#  {'qid': '49',
#   'ispass': False,
#   'label': '根據《針灸科學》,穴在足內踝上二寸,有兩個腎經的穴道,下列何者正確?',
#   'pred': '',
#   'nlabel': '根據針灸科學穴在足內踝上二寸有兩個腎經的穴道下列何者正確',
#   'npred': ''},
#  {'qid': '50',
#   'ispass': False,
#   'label': '關於內庭穴的敘述,下列何者錯誤?',
#   'pred': '笔为制宽输的明的把苹，以行是吧？',
#   'nlabel': '關於內庭穴的敘述下列何者錯誤',
#   'npred': '笔为制宽输的明的把苹以行是吧'},
#  {'qid': '51',
#   'ispass': False,
#   'label': '關於胸腹部的胃經穴位,下列敘述何者錯誤?',
#   'pred': '司为被江紫南的飯座内分，了合见做是一代错姐?。',
#   'nlabel': '關於胸腹部的胃經穴位下列敘述何者錯誤',
#   'npred': '司为被江紫南的飯座内分了合见做是一代错姐'},
#  {'qid': '52',
#   'ispass': False,
#   'label': '關於風池穴,下列敘述何者錯誤?',
#   'pred': '台为體沾崞，事一条名答一分错姐？',
#   'nlabel': '關於風池穴下列敘述何者錯誤',
#   'npred': '台为體沾崞事一条名答一分错姐'},
#  {'qid': '53',
#   'ispass': False,
#   'label': '有關「京門」穴之敘述,下列何者錯誤?',
#   'pred': '',
#   'nlabel': '有關京門穴之敘述下列何者錯誤',
#   'npred': ''},
#  {'qid': '54',
#   'ispass': True,
#   'label': '根據《針灸科學》,在膝關節內側屈膝橫紋頭陷中,為肝經何穴?',
#   'pred': '根據《針灸科學》，在膝關節內側屈膝橫紋頭陷中，為肝經何穴？',
#   'nlabel': '根據針灸科學在膝關節內側屈膝橫紋頭陷中為肝經何穴',
#   'npred': '根據針灸科學在膝關節內側屈膝橫紋頭陷中為肝經何穴'},
#  {'qid': '55',
#   'ispass': True,
#   'label': '有關「然谷」穴之敘述,下列何者錯誤?',
#   'pred': '有關「然谷」穴之敘述，下列何者錯誤？',
#   'nlabel': '有關然谷穴之敘述下列何者錯誤',
#   'npred': '有關然谷穴之敘述下列何者錯誤'},
#  {'qid': '56',
#   'ispass': False,
#   'label': '下列何穴不屬於督脈?',
#   'pred': '带代例不尺组海些?',
#   'nlabel': '下列何穴不屬於督脈',
#   'npred': '带代例不尺组海些'},
#  {'qid': '57',
#   'ispass': False,
#   'label': '關於腦戶穴的敘述,下列何者錯誤?',
#   'pred': '司为花崌维的注明的把答，以利。\n\nA. 确王名路回天为台对注明的南前，未名。\nB. 维的为条前，入子台一离，天注明内。\nC. 学给对。回的出崺入花崌一离，未注明。\nD. 使用食食台为对注明的安六。',
#   'nlabel': '關於腦戶穴的敘述下列何者錯誤',
#   'npred': '司为花崌维的注明的把答以利a确王名路回天为台对注明的南前未名b维的为条前入子台一离天注明内c学给对回的出崺入花崌一离未注明d使用食食台为对注明的安六'},
#  {'qid': '58',
#   'ispass': False,
#   'label': '龍虎交戰手法的組成,下列敘述何者正確?',
#   'pred': '累渊代歡又的合名，一七至定矩吗王名。',
#   'nlabel': '龍虎交戰手法的組成下列敘述何者正確',
#   'npred': '累渊代歡又的合名一七至定矩吗王名'},
#  {'qid': '59',
#   'ispass': False,
#   'label': '《內經》官針中,何種刺法不歸屬於放血的方法?',
#   'pred': '年例组服求中，为籿发的海沾。',
#   'nlabel': '內經官針中何種刺法不歸屬於放血的方法',
#   'npred': '年例组服求中为籿发的海沾'},
#  {'qid': '60',
#   'ispass': False,
#   'label': '有關灸法臨床適應症中,下列敘述共有幾項正確?1虛癆 2遺精 3冷哮 4多尿 5痺痛 6 胃痛',
#   'pred': '有關灸法臨床適應症中，下列敘述共有幾項正確？①虛癆\u3000②遺精\u3000③冷哮\u3000④多尿\u3000⑤痺痛\u3000⑥胃痛\n\nA.3\nB.4\nC.5\nD.6',
#   'nlabel': '有關灸法臨床適應症中下列敘述共有幾項正確1虛癆2遺精3冷哮4多尿5痺痛6胃痛',
#   'npred': '有關灸法臨床適應症中下列敘述共有幾項正確1虛癆2遺精3冷哮4多尿5痺痛6胃痛a3b4c5d6'},
#  {'qid': '61',
#   'ispass': False,
#   'label': '有關拔火罐的適應症,下列敘述共幾項正確?1外傷腰痛、肩背痛 2懷孕四個月以上孕婦腰骶部  3全身皮膚病或局部皮膚損傷 4腹痛、痛經 5局部麻痛 6胃痛、脅痛',
#   'pred': '发澟芷的分通览。一地名对为单五三七。发澟芷的分通览。一地名对为单五三七。发澟芷的分通览。一地名对为单五三七。发澟芷的分通览。',
#   'nlabel': '有關拔火罐的適應症下列敘述共幾項正確1外傷腰痛肩背痛2懷孕四個月以上孕婦腰骶部3全身皮膚病或局部皮膚損傷4腹痛痛經5局部麻痛6胃痛脅痛',
#   'npred': '发澟芷的分通览一地名对为单五三七发澟芷的分通览一地名对为单五三七发澟芷的分通览一地名对为单五三七发澟芷的分通览'},
#  {'qid': '62',
#   'ispass': True,
#   'label': '有關刺絡拔罐法的敘述,下列共幾項正確?1刺絡拔罐法,它是刺血法、拔罐法和經筋針法的綜合 運用 2重輥法則須出現皮膚塵粒樣出血 3輥刺拔罐法應先在治療部位作上下來回輥刺約二十分 鐘 4輥刺後進行拔罐時間約五至十分鐘 5刺絡拔罐屬於濕杯術 6散刺、叩刺拔罐法的重刺激 是以皮膚表面芝麻點狀出血為度',
#   'pred': '有關刺絡拔罐法的敘述，下列共幾項正確？①刺絡拔罐法，它是刺血法、拔罐法和經筋針法的綜合運用\u3000②重輥法則須出現皮膚塵粒樣出血\u3000③輥刺拔罐法應先在治療部位作上下來回輥刺約二十分鐘\u3000④輥刺後進行拔罐時間約五至十分鐘\u3000⑤刺絡拔罐屬於濕杯術\u3000⑥散刺、叩刺拔罐法的重刺激是以皮膚表面芝麻點狀出血為度',
#   'nlabel': '有關刺絡拔罐法的敘述下列共幾項正確1刺絡拔罐法它是刺血法拔罐法和經筋針法的綜合運用2重輥法則須出現皮膚塵粒樣出血3輥刺拔罐法應先在治療部位作上下來回輥刺約二十分鐘4輥刺後進行拔罐時間約五至十分鐘5刺絡拔罐屬於濕杯術6散刺叩刺拔罐法的重刺激是以皮膚表面芝麻點狀出血為度',
#   'npred': '有關刺絡拔罐法的敘述下列共幾項正確1刺絡拔罐法它是刺血法拔罐法和經筋針法的綜合運用2重輥法則須出現皮膚塵粒樣出血3輥刺拔罐法應先在治療部位作上下來回輥刺約二十分鐘4輥刺後進行拔罐時間約五至十分鐘5刺絡拔罐屬於濕杯術6散刺叩刺拔罐法的重刺激是以皮膚表面芝麻點狀出血為度'},
#  {'qid': '63',
#   'ispass': True,
#   'label': '應用刮痧療法時,如遇到「暈刮」現象及處理「暈刮」方式,下列敘述共幾項正確?1「暈刮」通 常是在刮拭過程中出現面色蒼白、噁心和冒冷汗等現象 2繼續強刺激刮拭,以使患者甦醒 3刮 拭過程中出現胸悶、心跳快速等現象可能是「暈刮」的現象 4按壓人中、內關等穴位 5讓患者 飲用熱開水',
#   'pred': '應用刮痧療法時，如遇到「暈刮」現象及處理「暈刮」方式，下列敘述共幾項正確？①"暈刮"通常是在刮拭過程中出現面色蒼白、噁心和冒冷汗等現象\u3000②繼續強刺激刮拭，以使患者甦醒\u3000③刮拭過程中出現胸悶、心跳快速等現象可能是"暈刮"的現象\u3000④按壓人中、內關等穴位\u3000⑤讓患者飲用熱開水',
#   'nlabel': '應用刮痧療法時如遇到暈刮現象及處理暈刮方式下列敘述共幾項正確1暈刮通常是在刮拭過程中出現面色蒼白噁心和冒冷汗等現象2繼續強刺激刮拭以使患者甦醒3刮拭過程中出現胸悶心跳快速等現象可能是暈刮的現象4按壓人中內關等穴位5讓患者飲用熱開水',
#   'npred': '應用刮痧療法時如遇到暈刮現象及處理暈刮方式下列敘述共幾項正確1暈刮通常是在刮拭過程中出現面色蒼白噁心和冒冷汗等現象2繼續強刺激刮拭以使患者甦醒3刮拭過程中出現胸悶心跳快速等現象可能是暈刮的現象4按壓人中內關等穴位5讓患者飲用熱開水'},
#  {'qid': '64',
#   'ispass': False,
#   'label': '有關顏面神經麻痺的治療方法與注意事項何者最不適當?',
#   'pred': '常代秀浦纨的复加有台和啊品是。常代秀浦纨的复加有台咂、常代秀浦纨的啊品咂、常代秀浦纨的得加咂、常代秀浦纨的台品咂',
#   'nlabel': '有關顏面神經麻痺的治療方法與注意事項何者最不適當',
#   'npred': '常代秀浦纨的复加有台和啊品是常代秀浦纨的复加有台咂常代秀浦纨的啊品咂常代秀浦纨的得加咂常代秀浦纨的台品咂'},
#  {'qid': '65',
#   'ispass': False,
#   'label': '下列何穴無法用於氣血兩虛型頭痛的治療?',
#   'pred': '下列何穴無法用於氣血兩虛型頭痛的治療？\n\nA.膻中\nB.太衝\nC.足三里\nD.三陰交',
#   'nlabel': '下列何穴無法用於氣血兩虛型頭痛的治療',
#   'npred': '下列何穴無法用於氣血兩虛型頭痛的治療a膻中b太衝c足三里d三陰交'},
#  {'qid': '66',
#   'ispass': False,
#   'label': '下列有關坐骨神經痛的敘述何者錯誤?',
#   'pred': '常代种欢飒的明给、最连是错度?',
#   'nlabel': '下列有關坐骨神經痛的敘述何者錯誤',
#   'npred': '常代种欢飒的明给最连是错度'},
#  {'qid': '67',
#   'ispass': False,
#   'label': '針灸治療腕隧道症候群,取下列何穴治療?',
#   'pred': '笔动化明得发含翰代权公囯，卩刪了吗切有截苹起消得）',
#   'nlabel': '針灸治療腕隧道症候群取下列何穴治療',
#   'npred': '笔动化明得发含翰代权公囯卩刪了吗切有截苹起消得'},
#  {'qid': '68',
#   'ispass': True,
#   'label': '寒流過境後突發急性腰痛,下列治療何者最適當?',
#   'pred': '寒流過境後突發急性腰痛，下列治療何者最適當？',
#   'nlabel': '寒流過境後突發急性腰痛下列治療何者最適當',
#   'npred': '寒流過境後突發急性腰痛下列治療何者最適當'},
#  {'qid': '69',
#   'ispass': False,
#   'label': '食用海鮮後誘發皮膚過敏,蕁麻疹發作,針灸治療應選下列何穴?',
#   'pred': '',
#   'nlabel': '食用海鮮後誘發皮膚過敏蕁麻疹發作針灸治療應選下列何穴',
#   'npred': ''},
#  {'qid': '70',
#   'ispass': True,
#   'label': '以針灸治療牙痛時,下列敘述共幾項正確?1先針痛側合谷穴,針斜向上而刺入皮膚 2無法止痛 時加內庭、下關、頰車、耳門 3熬夜牙痛用針灸之外加藥物較佳 4合谷穴採雀啄術',
#   'pred': '以針灸治療牙痛時，下列敘述共幾項正確？①先針痛側合谷穴，針斜向上而刺入皮膚\u3000②無法止痛時加內庭、下關、頰車、耳門\u3000③熬夜牙痛用針灸之外加藥物較佳\u3000④合谷穴採雀啄術',
#   'nlabel': '以針灸治療牙痛時下列敘述共幾項正確1先針痛側合谷穴針斜向上而刺入皮膚2無法止痛時加內庭下關頰車耳門3熬夜牙痛用針灸之外加藥物較佳4合谷穴採雀啄術',
#   'npred': '以針灸治療牙痛時下列敘述共幾項正確1先針痛側合谷穴針斜向上而刺入皮膚2無法止痛時加內庭下關頰車耳門3熬夜牙痛用針灸之外加藥物較佳4合谷穴採雀啄術'},
#  {'qid': '71',
#   'ispass': True,
#   'label': '呼吸照護病房中一位90歲患者,因多日腹瀉出現脫肛現象,會診中醫,下列有關治療之敘述,共有 幾項正確?1可針長強穴 2可灸百會穴 3可隔鹽灸神闕穴 4可選膀胱經的合穴承山穴',
#   'pred': '呼吸照護病房中一位90歲患者，因多日腹瀉出現脫肛現象，會診中醫，下列有關治療之敘述，共有幾項正確？①可針長強穴\u3000②可灸百會穴\u3000③可隔鹽灸神闕穴\u3000④可選膀胱經的合穴承山穴',
#   'nlabel': '呼吸照護病房中一位90歲患者因多日腹瀉出現脫肛現象會診中醫下列有關治療之敘述共有幾項正確1可針長強穴2可灸百會穴3可隔鹽灸神闕穴4可選膀胱經的合穴承山穴',
#   'npred': '呼吸照護病房中一位90歲患者因多日腹瀉出現脫肛現象會診中醫下列有關治療之敘述共有幾項正確1可針長強穴2可灸百會穴3可隔鹽灸神闕穴4可選膀胱經的合穴承山穴'},
#  {'qid': '72',
#   'ispass': True,
#   'label': '預防大腸癌應養成規律排便習慣,改善便秘的穴位中,下列敘述共幾項正確?1天樞穴屬胃經,是 大腸會穴 2老人虛秘可以選用氣海穴和關元穴 3照海穴屬腎經,可調理臟腑 4支溝穴可清利 三焦氣機',
#   'pred': '預防大腸癌應養成規律排便習慣，改善便秘的穴位中，下列敘述共幾項正確？①天樞穴屬胃經，是大腸會穴\u3000②老人虛秘可以選用氣海穴和關元穴\u3000③照海穴屬腎經，可調理臟腑\u3000④支溝穴可清利三焦氣機',
#   'nlabel': '預防大腸癌應養成規律排便習慣改善便秘的穴位中下列敘述共幾項正確1天樞穴屬胃經是大腸會穴2老人虛秘可以選用氣海穴和關元穴3照海穴屬腎經可調理臟腑4支溝穴可清利三焦氣機',
#   'npred': '預防大腸癌應養成規律排便習慣改善便秘的穴位中下列敘述共幾項正確1天樞穴屬胃經是大腸會穴2老人虛秘可以選用氣海穴和關元穴3照海穴屬腎經可調理臟腑4支溝穴可清利三焦氣機'},
#  {'qid': '73',
#   'ispass': False,
#   'label': '32歲婦女懷孕第一胎,懷孕週數14週,經常孕吐而來求診,下列何者為妊娠嘔吐的特效穴?',
#   'pred': '73.32歲婦女懷孕第一胎，懷孕週數14週，經常孕吐而來求診，下列何者為妊娠嘔吐的特效穴？',
#   'nlabel': '32歲婦女懷孕第一胎懷孕週數14週經常孕吐而來求診下列何者為妊娠嘔吐的特效穴',
#   'npred': '7332歲婦女懷孕第一胎懷孕週數14週經常孕吐而來求診下列何者為妊娠嘔吐的特效穴'},
#  {'qid': '74',
#   'ispass': False,
#   'label': '45歲女性患者乾咳,痰少,夜咳,痰中帶血絲,掌心胸口微熱,顴紅,脈細數。若用針灸處方,下 列那一組穴位比較適當?',
#   'pred': '若用針灸處方，下列那一組穴位比較適當？',
#   'nlabel': '45歲女性患者乾咳痰少夜咳痰中帶血絲掌心胸口微熱顴紅脈細數若用針灸處方下列那一組穴位比較適當',
#   'npred': '若用針灸處方下列那一組穴位比較適當'},
#  {'qid': '75',
#   'ispass': False,
#   'label': '下列那一組穴位最適合治療風熱感冒?',
#   'pred': '笭小三分台訽工、六度天、南种名别',
#   'nlabel': '下列那一組穴位最適合治療風熱感冒',
#   'npred': '笭小三分台訽工六度天南种名别'},
#  {'qid': '76',
#   'ispass': False,
#   'label': '治療嘔血、衄血,下列那一經穴最不適當?',
#   'pred': '經年殏飯，芫加右，芫龙王，代码的经分已一中其前路度有事为一台经分。',
#   'nlabel': '治療嘔血衄血下列那一經穴最不適當',
#   'npred': '經年殏飯芫加右芫龙王代码的经分已一中其前路度有事为一台经分'},
#  {'qid': '77',
#   'ispass': False,
#   'label': '患者長期睡眠不佳,心中懊憹,脘悶噫氣、噯腐吞酸,苔厚膩,脈滑。治療選擇心經及背俞外,會 再選擇那一組經脈之穴位?',
#   'pred': '治療選擇心經及背俞外，會再選擇那一組經脈之穴位？',
#   'nlabel': '患者長期睡眠不佳心中懊憹脘悶噫氣噯腐吞酸苔厚膩脈滑治療選擇心經及背俞外會再選擇那一組經脈之穴位',
#   'npred': '治療選擇心經及背俞外會再選擇那一組經脈之穴位'},
#  {'qid': '78',
#   'ispass': False,
#   'label': '有關陽痿針灸治療的敘述,下列何者正確?1陽痿主要與肝脾腎相關,可取任脈與足三陰經交會穴 關元和足三陰交會穴三陰交治療 2選取肝經原穴與俞穴:太衝,可以達到疏肝理氣的作用 3可 選用任脈與足三陰經的會穴,也是膀胱經的募穴:中極;中極及曲骨兩穴合用具有清利濕熱,培元 理氣的作用 4蠡溝是肝經之絡穴,別走少陽膽經,也有疏肝理氣的作用',
#   'pred': '常是大海参代难化有亡的合明，了三一条、寸演窑分和角五分右子的合明，、寸演窑分和角五分右子的合明。',
#   'nlabel': '有關陽痿針灸治療的敘述下列何者正確1陽痿主要與肝脾腎相關可取任脈與足三陰經交會穴關元和足三陰交會穴三陰交治療2選取肝經原穴與俞穴太衝可以達到疏肝理氣的作用3可選用任脈與足三陰經的會穴也是膀胱經的募穴中極中極及曲骨兩穴合用具有清利濕熱培元理氣的作用4蠡溝是肝經之絡穴別走少陽膽經也有疏肝理氣的作用',
#   'npred': '常是大海参代难化有亡的合明了三一条寸演窑分和角五分右子的合明寸演窑分和角五分右子的合明'},
#  {'qid': '79',
#   'ispass': True,
#   'label': '有關針灸治療痛經的敘述,下列何者錯誤?',
#   'pred': '有關針灸治療痛經的敘述，下列何者錯誤？',
#   'nlabel': '有關針灸治療痛經的敘述下列何者錯誤',
#   'npred': '有關針灸治療痛經的敘述下列何者錯誤'},
#  {'qid': '80',
#   'ispass': True,
#   'label': '有關針灸治療小兒麻痺後遺症之敘述,下列何者錯誤?',
#   'pred': '有關針灸治療小兒麻痺後遺症之敘述，下列何者錯誤？',
#   'nlabel': '有關針灸治療小兒麻痺後遺症之敘述下列何者錯誤',
#   'npred': '有關針灸治療小兒麻痺後遺症之敘述下列何者錯誤'}]

# %%
# check by ispass
CNT = 0
labels = []
pred_scores = []

for idx, label in enumerate(label_data):
    qid = label['qid']
    if label['ispass']:
        labels.append(1)
    else:
        labels.append(0)

    correctness = eval_data[qid]
    pred_score = (correctness['score'] - 1 )/ 4
    pred_scores.append(pred_score)

    if (label['ispass'] != correctness['ispass']):
        CNT+=1
        print(f'-----{CNT}')
        print(f"label: {label['ispass']}, 'evaluator: {correctness['ispass']}")
        print("# reference_answer")
        print(correctness['reference_answer'])
        print("# response")
        print(correctness['response'])
        print("# feedback")
        print(correctness['feedback'])
        print("# score")
        print(correctness['score'])
# Out:
# -----1
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '7', 'stem': '依《難經.六十八難》,下列何穴主心下滿?', 'A': '前谷', 'B': '液門', 'C': '湧泉', 'D': '跗陽'}
# # response
# {'A': '前谷', 'B': '液門', 'C': '湧泉', 'D': '跗陽', 'qid': '7', 'stem': '依《難經．六十八難》，下列何穴主心下滿？'}
# # feedback
# 生成答案與參考答案在內容上完全一致（qid、stem 及各選項均有正確擷取），但欄位順序與原始題目不同（stem 放在最後），依說明此類「stem 與原始順序不一致」視為錯誤，故給中等分數。
# # score
# 3.0
# -----2
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '12', 'stem': '下列何穴最適合治療瘰癧?', 'A': '小海', 'B': '尺澤', 'C': '曲澤', 'D': '天井'}
# # response
# {'A': '小海', 'B': '尺澤', 'C': '曲澤', 'D': '天井', 'qid': 12, 'stem': '下列何穴最適合治療瘰癧？'}
# # feedback
# 生成答案的題幹與四個選項與參考答案內容完全一致，但 qid 為整數 12 而參考答案為字串 '12'，依規則「qid 提取錯誤視為錯誤」，因此給予中等扣分處理。
# # score
# 3.0
# -----3
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '25', 'stem': '有關中風患者使用頭皮針之技術,下列敘述何者錯誤?', 'A': '適用於中風後半身不遂之患者', 'B': '撚針同時不建議病人做患肢運動,以免增加出血可能性', 'C': '沿頭皮下刺入五分至一寸', 'D': '根據患者臨床症狀選取運動區、語言區或足運感區等針刺治療'}
# # response
# {'A': 'B.撚針同時不建議病人做患肢運動，以免增加出血可能性', 'B': 'C.沿頭皮下刺入五分至一寸', 'C': 'D.根據患者臨床症狀選取運動區、語言區或足運感區等針刺治療', 'D': 'A.適用於中風後半身不遂之患者', 'qid': 25, 'stem': '有關中風患者使用頭皮針之技術，下列敘述何者錯誤？'}
# # feedback
# 生成答案雖然抓到 qid 與 stem，且四個選項文字都有出現，但選項標號被錯置（例如輸出欄位 A 內實為原選項 B 的內容，B 內為原 C，依此類推），因此標示不正確，屬於相關但有錯誤的提取。
# # score
# 3.0
# -----4
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '39', 'stem': '根據《靈樞.經脈》,關於足陽明胃經的循行及病候敘述,下列何者錯誤?', 'A': '其支者,從大迎前下人迎,循喉嚨,入缺盆', 'B': '下膝臏中,下循脛內廉,下足跗,入大趾內間', 'C': '所生病者......頸腫喉痹,大腹水腫,膝臏腫痛', 'D': '是動則病,灑灑振寒,善呻數欠,顏黑'}
# # response
# {'A': '其支者，從大迎前下人迎，循喉嚨，入缺盆', 'B': '下膝臏中，下循脛內廉，下足跗，入大趾內間', 'C': '所生病者……頸腫喉痹，大腹水腫，膝臏腫痛', 'D': '是動則病，灑灑振寒，善呻數欠，顏黑', 'qid': '40', 'stem': '根據《靈樞．經脈》，關於足陽明胃經的循行及病候敘述，下列何者錯誤？'}
# # feedback
# 生成答案的題幹與選項內容與參考答案一致、完整擷取出題幹與 A–D 選項，但 qid 標為 '40'（應為 '39'），根據評分準則「qid 提取錯誤，視為錯誤」，因此給予部分分數。
# # score
# 3.0
# -----5
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '54', 'stem': '根據《針灸科學》,在膝關節內側屈膝橫紋頭陷中,為肝經何穴?', 'A': '陰谷', 'B': '陽谷', 'C': '曲泉', 'D': '委中'}
# # response
# {'A': '秀崯', 'B': '首崯', 'C': '窋游', 'D': '问三医', 'qid': '54', 'stem': '根據《針灸科學》，在膝關節內側屈膝橫紋頭陷中，為肝經何穴？'}
# # feedback
# 生成答案與使用者問題相關且包含正確的 qid 與 stem，但選項內容完全錯誤（與參考答案的 A/B/C/D 不符且為無意義或錯誤文字），因此為有關聯但包含重大錯誤，給予 2 分。
# # score
# 2.0
# -----6
# label: False, 'evaluator: True
# # reference_answer
# {'qid': '60', 'stem': '有關灸法臨床適應症中,下列敘述共有幾項正確?1虛癆 2遺精 3冷哮 4多尿 5痺痛 6 胃痛', 'A': '3', 'B': '4', 'C': '5', 'D': '6'}
# # response
# {'A': 'A.3', 'B': 'B.4', 'C': 'C.5', 'D': 'D.6', 'qid': '60', 'stem': '有關灸法臨床適應症中，下列敘述共有幾項正確？①虛癆\u3000②遺精\u3000③冷哮\u3000④多尿\u3000⑤痺痛\u3000⑥胃痛\n\nA.3\nB.4\nC.5\nD.6'}
# # feedback
# 生成答案完整擷取出 qid（60）、題幹與四個選項，且選項對應內容與參考答案一致；唯一小差異是選項值包含了前綴如 "A.3" 而非純數字格式，屬格式差異不影響正確性。
# # score
# 5.0
# -----7
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '63', 'stem': '應用刮痧療法時,如遇到「暈刮」現象及處理「暈刮」方式,下列敘述共幾項正確?1「暈刮」通 常是在刮拭過程中出現面色蒼白、噁心和冒冷汗等現象 2繼續強刺激刮拭,以使患者甦醒 3刮 拭過程中出現胸悶、心跳快速等現象可能是「暈刮」的現象 4按壓人中、內關等穴位 5讓患者 飲用熱開水', 'A': '2', 'B': '3', 'C': '4', 'D': '5'}
# # response
# {'A': 'B.3', 'B': 'C.4', 'C': 'D.5', 'ans': 'B', 'qid': '64', 'stem': '應用刮痧療法時，如遇到「暈刮」現象及處理「暈刮」方式，下列敘述共幾項正確？①"暈刮"通常是在刮拭過程中出現面色蒼白、噁心和冒冷汗等現象\u3000②繼續強刺激刮拭，以使患者甦醒\u3000③刮拭過程中出現胸悶、心跳快速等現象可能是"暈刮"的現象\u3000④按壓人中、內關等穴位\u3000⑤讓患者飲用熱開水'}
# # feedback
# 生成答案與題幹相關但有多項錯誤：qid 抽出錯誤（產生為 '64'，參考為 '63'），選項內容被錯置/格式錯誤（A/B/C 不對應原始選項），且在原文未提供答案時錯誤地加入了 ans 欄（還標為 B）。僅題幹提取大致正確，故給分為 2。
# # score
# 2.0
# -----8
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '68', 'stem': '寒流過境後突發急性腰痛,下列治療何者最適當?', 'A': '委中穴刺絡放血', 'B': '針刺後谿、申脈加拔罐', 'C': '針刺足三里、三陰交加電針', 'D': '針刺腎俞、大腸俞加針上灸'}
# # response
# {'A': '委中穴刺絡放血', 'B': '針刺後谿、申脈加拔罐', 'C': '針刺足三里、三陰交加電針', 'D': '針刺腎俞、大腸俞加針上灸', 'qid': '69', 'stem': '寒流過境後突發急性腰痛，下列治療何者最適當？'}
# # feedback
# 生成答案與參考答案內容相關且選項相符，但存在重大提取/格式錯誤：qid 提取錯誤（生成 qid='69'，參考為 '68'），且欄位順序改變（stem 未維持原位置），依評分準則視為錯誤，故給 2 分。
# # score
# 2.0
# -----9
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '79', 'stem': '有關針灸治療痛經的敘述,下列何者錯誤?', 'A': '八髎穴是治療腰痛與盆腔疾病重要穴位', 'B': '上髎穴是膀胱經與腎經交會穴', 'C': '若失血較少時,可用艾柱隔薑灸神闕、隱白、腰陽關', 'D': '陽陵泉為膽經合穴,太衝為肝經原穴,兩者配合可以疏肝利膽、理氣調經'}
# # response
# {'A': 'B. 上髎穴是膀胱經與腎經交會穴', 'B': 'C. 若失血較少時，可用艾柱隔薑灸神闕、隱白、腰陽關', 'C': 'D. 陽陵泉為膽經合穴，太衝為肝經原穴，兩者配合可以疏肝利膽、理氣調經', 'D': 'A. 八髎穴是治療腰痛與盆腔疾病重要穴位', 'qid': '79', 'stem': '有關針灸治療痛經的敘述，下列何者錯誤？'}
# # feedback
# 生成答案擷取出了 qid 與題幹，但選項標號與內容被錯誤對應（A 寫成原 B 的文字，B 寫成原 C，C 寫成原 D，D 寫成原 A），因此選項標示不正確，屬於相關但有錯誤的輸出。
# # score
# 3.0

# %%
# check by score
CNT = 0
labels = []
pred_scores = []

for idx, label in enumerate(label_data):
    qid = label['qid']
    if label['ispass']:
        labels.append(1)
    else:
        labels.append(0)

    correctness = eval_data[qid]
    pred_score = (correctness['score'] - 1 )/ 4
    pred_scores.append(pred_score)

    if int(correctness['score']) != 5:
        correctness['ispass'] = False

    if (label['ispass'] != correctness['ispass']):
        CNT+=1
        print(f'-----{CNT}')
        print(f"label: {label['ispass']}, 'evaluator: {correctness['ispass']}")
        print("# reference_answer")
        print(correctness['reference_answer'])
        print("# response")
        print(correctness['response'])
        print("# feedback")
        print(correctness['feedback'])
        print("# score")
        print(correctness['score'])
# Out:
# -----1
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '5', 'stem': '下列何者為陰維脈之郄穴?', 'A': '交信', 'B': '築賓', 'C': '府舍', 'D': '腹哀'}
# # response
# {'A': 'A. 交信', 'B': 'B. 築賓', 'C': 'C. 府舍', 'D': 'D. 腹哀', 'ans': '', 'qid': '5', 'stem': '下列何者為陰維脈之郄穴?'}
# # feedback
# 生成答案與參考答案在題號、題幹與選項內容上均正確且相關；唯有格式上小瑕疵——原指示要求若無答案則省略答案欄，但系統答案包含了空的 'ans' 欄（且選項值帶有冗餘的 "A. "、"B. " 標記），屬格式／呈現問題但不影響內容正確性。
# # score
# 4.0
# -----2
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '7', 'stem': '依《難經.六十八難》,下列何穴主心下滿?', 'A': '前谷', 'B': '液門', 'C': '湧泉', 'D': '跗陽'}
# # response
# {'A': '前谷', 'B': '液門', 'C': '湧泉', 'D': '跗陽', 'qid': '7', 'stem': '依《難經．六十八難》，下列何穴主心下滿？'}
# # feedback
# 生成答案與參考答案在內容上完全一致（qid、stem 及各選項均有正確擷取），但欄位順序與原始題目不同（stem 放在最後），依說明此類「stem 與原始順序不一致」視為錯誤，故給中等分數。
# # score
# 3.0
# -----3
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '12', 'stem': '下列何穴最適合治療瘰癧?', 'A': '小海', 'B': '尺澤', 'C': '曲澤', 'D': '天井'}
# # response
# {'A': '小海', 'B': '尺澤', 'C': '曲澤', 'D': '天井', 'qid': 12, 'stem': '下列何穴最適合治療瘰癧？'}
# # feedback
# 生成答案的題幹與四個選項與參考答案內容完全一致，但 qid 為整數 12 而參考答案為字串 '12'，依規則「qid 提取錯誤視為錯誤」，因此給予中等扣分處理。
# # score
# 3.0
# -----4
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '25', 'stem': '有關中風患者使用頭皮針之技術,下列敘述何者錯誤?', 'A': '適用於中風後半身不遂之患者', 'B': '撚針同時不建議病人做患肢運動,以免增加出血可能性', 'C': '沿頭皮下刺入五分至一寸', 'D': '根據患者臨床症狀選取運動區、語言區或足運感區等針刺治療'}
# # response
# {'A': 'B.撚針同時不建議病人做患肢運動，以免增加出血可能性', 'B': 'C.沿頭皮下刺入五分至一寸', 'C': 'D.根據患者臨床症狀選取運動區、語言區或足運感區等針刺治療', 'D': 'A.適用於中風後半身不遂之患者', 'qid': 25, 'stem': '有關中風患者使用頭皮針之技術，下列敘述何者錯誤？'}
# # feedback
# 生成答案雖然抓到 qid 與 stem，且四個選項文字都有出現，但選項標號被錯置（例如輸出欄位 A 內實為原選項 B 的內容，B 內為原 C，依此類推），因此標示不正確，屬於相關但有錯誤的提取。
# # score
# 3.0
# -----5
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '39', 'stem': '根據《靈樞.經脈》,關於足陽明胃經的循行及病候敘述,下列何者錯誤?', 'A': '其支者,從大迎前下人迎,循喉嚨,入缺盆', 'B': '下膝臏中,下循脛內廉,下足跗,入大趾內間', 'C': '所生病者......頸腫喉痹,大腹水腫,膝臏腫痛', 'D': '是動則病,灑灑振寒,善呻數欠,顏黑'}
# # response
# {'A': '其支者，從大迎前下人迎，循喉嚨，入缺盆', 'B': '下膝臏中，下循脛內廉，下足跗，入大趾內間', 'C': '所生病者……頸腫喉痹，大腹水腫，膝臏腫痛', 'D': '是動則病，灑灑振寒，善呻數欠，顏黑', 'qid': '40', 'stem': '根據《靈樞．經脈》，關於足陽明胃經的循行及病候敘述，下列何者錯誤？'}
# # feedback
# 生成答案的題幹與選項內容與參考答案一致、完整擷取出題幹與 A–D 選項，但 qid 標為 '40'（應為 '39'），根據評分準則「qid 提取錯誤，視為錯誤」，因此給予部分分數。
# # score
# 3.0
# -----6
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '54', 'stem': '根據《針灸科學》,在膝關節內側屈膝橫紋頭陷中,為肝經何穴?', 'A': '陰谷', 'B': '陽谷', 'C': '曲泉', 'D': '委中'}
# # response
# {'A': '秀崯', 'B': '首崯', 'C': '窋游', 'D': '问三医', 'qid': '54', 'stem': '根據《針灸科學》，在膝關節內側屈膝橫紋頭陷中，為肝經何穴？'}
# # feedback
# 生成答案與使用者問題相關且包含正確的 qid 與 stem，但選項內容完全錯誤（與參考答案的 A/B/C/D 不符且為無意義或錯誤文字），因此為有關聯但包含重大錯誤，給予 2 分。
# # score
# 2.0
# -----7
# label: False, 'evaluator: True
# # reference_answer
# {'qid': '60', 'stem': '有關灸法臨床適應症中,下列敘述共有幾項正確?1虛癆 2遺精 3冷哮 4多尿 5痺痛 6 胃痛', 'A': '3', 'B': '4', 'C': '5', 'D': '6'}
# # response
# {'A': 'A.3', 'B': 'B.4', 'C': 'C.5', 'D': 'D.6', 'qid': '60', 'stem': '有關灸法臨床適應症中，下列敘述共有幾項正確？①虛癆\u3000②遺精\u3000③冷哮\u3000④多尿\u3000⑤痺痛\u3000⑥胃痛\n\nA.3\nB.4\nC.5\nD.6'}
# # feedback
# 生成答案完整擷取出 qid（60）、題幹與四個選項，且選項對應內容與參考答案一致；唯一小差異是選項值包含了前綴如 "A.3" 而非純數字格式，屬格式差異不影響正確性。
# # score
# 5.0
# -----8
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '63', 'stem': '應用刮痧療法時,如遇到「暈刮」現象及處理「暈刮」方式,下列敘述共幾項正確?1「暈刮」通 常是在刮拭過程中出現面色蒼白、噁心和冒冷汗等現象 2繼續強刺激刮拭,以使患者甦醒 3刮 拭過程中出現胸悶、心跳快速等現象可能是「暈刮」的現象 4按壓人中、內關等穴位 5讓患者 飲用熱開水', 'A': '2', 'B': '3', 'C': '4', 'D': '5'}
# # response
# {'A': 'B.3', 'B': 'C.4', 'C': 'D.5', 'ans': 'B', 'qid': '64', 'stem': '應用刮痧療法時，如遇到「暈刮」現象及處理「暈刮」方式，下列敘述共幾項正確？①"暈刮"通常是在刮拭過程中出現面色蒼白、噁心和冒冷汗等現象\u3000②繼續強刺激刮拭，以使患者甦醒\u3000③刮拭過程中出現胸悶、心跳快速等現象可能是"暈刮"的現象\u3000④按壓人中、內關等穴位\u3000⑤讓患者飲用熱開水'}
# # feedback
# 生成答案與題幹相關但有多項錯誤：qid 抽出錯誤（產生為 '64'，參考為 '63'），選項內容被錯置/格式錯誤（A/B/C 不對應原始選項），且在原文未提供答案時錯誤地加入了 ans 欄（還標為 B）。僅題幹提取大致正確，故給分為 2。
# # score
# 2.0
# -----9
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '68', 'stem': '寒流過境後突發急性腰痛,下列治療何者最適當?', 'A': '委中穴刺絡放血', 'B': '針刺後谿、申脈加拔罐', 'C': '針刺足三里、三陰交加電針', 'D': '針刺腎俞、大腸俞加針上灸'}
# # response
# {'A': '委中穴刺絡放血', 'B': '針刺後谿、申脈加拔罐', 'C': '針刺足三里、三陰交加電針', 'D': '針刺腎俞、大腸俞加針上灸', 'qid': '69', 'stem': '寒流過境後突發急性腰痛，下列治療何者最適當？'}
# # feedback
# 生成答案與參考答案內容相關且選項相符，但存在重大提取/格式錯誤：qid 提取錯誤（生成 qid='69'，參考為 '68'），且欄位順序改變（stem 未維持原位置），依評分準則視為錯誤，故給 2 分。
# # score
# 2.0
# -----10
# label: True, 'evaluator: False
# # reference_answer
# {'qid': '79', 'stem': '有關針灸治療痛經的敘述,下列何者錯誤?', 'A': '八髎穴是治療腰痛與盆腔疾病重要穴位', 'B': '上髎穴是膀胱經與腎經交會穴', 'C': '若失血較少時,可用艾柱隔薑灸神闕、隱白、腰陽關', 'D': '陽陵泉為膽經合穴,太衝為肝經原穴,兩者配合可以疏肝利膽、理氣調經'}
# # response
# {'A': 'B. 上髎穴是膀胱經與腎經交會穴', 'B': 'C. 若失血較少時，可用艾柱隔薑灸神闕、隱白、腰陽關', 'C': 'D. 陽陵泉為膽經合穴，太衝為肝經原穴，兩者配合可以疏肝利膽、理氣調經', 'D': 'A. 八髎穴是治療腰痛與盆腔疾病重要穴位', 'qid': '79', 'stem': '有關針灸治療痛經的敘述，下列何者錯誤？'}
# # feedback
# 生成答案擷取出了 qid 與題幹，但選項標號與內容被錯誤對應（A 寫成原 B 的文字，B 寫成原 C，C 寫成原 D，D 寫成原 A），因此選項標示不正確，屬於相關但有錯誤的輸出。
# # score
# 3.0

# %% [markdown]
# # summary

# %%
# False Positive:
qid: 5, 7, 12
# False Negative
qid: 60
